# %% [markdown]
# # Connect to FTP server and download the data

# %% [markdown]
# ##### imort

# %%
import ftplib
import os
from datetime import datetime

# %% [markdown]
# ##### functions

# %%
# some utility functions that we gonna need
def get_size_format(n, suffix="B"):
    # converts bytes to scaled format (e.g KB, MB, etc.)
    for unit in ["", "K", "M", "G", "T", "P"]:
        if n < 1024:
            return f"{n:.2f}{unit}{suffix}"
        n /= 1024

def get_datetime_format(date_time):
    # convert to datetime object
    date_time = datetime.strptime(date_time, "%Y%m%d%H%M%S")
    # convert to human readable date time string
    return date_time.strftime("%Y/%m/%d %H:%M:%S")

# %% [markdown]
# _________________________

# %%
FTP_HOST = 'opendata.dwd.de'
#FTP_USER = 'USER'
#FTP_PASS = 'PASS'

# initialize FTP session
ftp = ftplib.FTP(host=FTP_HOST)
# force UTF-8 encoding
ftp.encoding = "utf-8"
# print the welcome message
print(ftp.getwelcome())
# Out:
# 220 Welcome to DWD's opendata FTP service.

# %% [markdown]
# #### Let's get some precipitation data

# %%
ftp.cwd('climate_environment/CDC/observations_germany/climate/annual/more_precip/recent')
# Out:
# ---------------------------------------------------------------------------
# error_perm                                Traceback (most recent call last)
# <ipython-input-23-fdce7df48bfc> in <module>
# ----> 1 ftp.cwd('climate_environment/CDC/observations_germany/climate/annual/more_precip/recent')
#
# ~\.conda\envs\eo_dev\lib\ftplib.py in cwd(self, dirname)
#     629             dirname = '.'  # does nothing, but could return error
#     630         cmd = 'CWD ' + dirname
# --> 631         return self.voidcmd(cmd)
#     632
#     633     def size(self, filename):
#
# ~\.conda\envs\eo_dev\lib\ftplib.py in voidcmd(self, cmd)
#     276         """Send a command and expect a response beginning with '2'."""
#     277         self.putcmd(cmd)
# --> 278         return self.voidresp()
#     279
#     280     def sendport(self, host, port):
#
# ~\.conda\envs\eo_dev\lib\ftplib.py in voidresp(self)
#     249     def voidresp(self):
#     250         """Expect a response beginning with '2'."""
# ...
